# %%
import pandas as pd
import geopandas as gpd
#traffic volume csv
closed_streets=pd.read_csv('https://raw.githubusercontent.com/AlejandraZS10/capstone_project/master/closed_streets.csv')
closed_streets.head(5)
# Out:
#    Unnamed: 0  NODEID                           ONSTREETNAME   FROMSTREETNAME  \
# 0           0   13010                           canal avenue    w   17 street
# 1           1   13011  belt  parkway eb en cropsey avenue sb  bay   52 street
# 2           2  108018                    riverside boulevard    w   63 street
# 3           3  101964                              87 avenue       233 street
# 4           4   17361                               avenue k    e    7 street
#
#   BOROUGH_CODE      WORK_START_DATE        WORK_END_DATE  \
# 0            B  05/17/2018 00:00:00  05/21/2018 23:59:59
# 1            B  05/17/2018 00:00:00  05/21/2018 23:59:59
# 2            M  12/04/2017 00:00:00  12/05/2017 23:59:59
# 3            Q  10/06/2017 14:10:27  01/01/2018 23:58:59
# 4            B  07/31/2017 00:00:00  08/02/2017 23:59:59
#
#                                    PURPOSE             DateTime  \
# 0                      DOT IN-HOUSE PAVING  2018-05-17 00:00:00
# ...

# %%
closed_streets.dtypes
# Out:
# Unnamed: 0          int64
# NODEID              int64
# ONSTREETNAME       object
# FROMSTREETNAME     object
# BOROUGH_CODE       object
# WORK_START_DATE    object
# WORK_END_DATE      object
# PURPOSE            object
# DateTime           object
# DateTimeEnd        object
# Date               object
# Time               object
# year                int64
# month               int64
# day                 int64
# DateEnd            object
# difference         object
# dtype: object

# %%
# Dropping old Name columns
closed_streets.drop(columns =["Unnamed: 0","WORK_START_DATE","WORK_END_DATE","PURPOSE"], inplace = True)

# %%
closed_streets.to_csv('closed_streets.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-6adeee8fd6c8> in <module>
# ----> 1 closed_streets.to_csv('closed_streets.csv', index_col=0)
#
# TypeError: to_csv() got an unexpected keyword argument 'index_col'
