# %% [markdown]
# A geojson file with all streets in the five boroughs of New York. The file serves as a database of all existing streets.
#
# This file adds a new unique ID to every street to keep track of spatial connections with other databases.

# %%
import pandas as pd
import geopandas as gpd
#all streets in New York
scl = gpd.read_file('data/NYC Street Centerline (CSCL).geojson')
scl
# Out:
#        rw_type l_low_hn pre_direct st_width  r_zip r_low_hn bike_lane  \
# 0            1       50       None       42  10280       51      None
# 1            1       66       None       42  10280       65      None
# 2            1       84       None       42  10280       83      None
# 3            1     None       None       42  10280     None      None
# 4            1     None       None       24  10004     None      None
# ...        ...      ...        ...      ...    ...      ...       ...
# 120167       6     None       None        0  10475     None      None
# 120168       6     None       None        0  10475     None      None
# 120169       1     None       None       45  10454     None         2
# 120170       1     None       None       45  10454     None         2
# 120171       1     None       None        0  10454     None      None
#
#        post_type  r_blkfc_id bike_trafd  ... snow_pri borocode trafdir  \
# 0             PL  1222601917       None  ...        C        1      TW
# 1             PL  1222604562       None  ...        C        1      TW
# 2             PL  1222600933       None  ...        C        1      TW
# 3             PL  1222600931       None  ...        C        1      TW
# 4             PL   212262395       None  ...        C        1      TF
# ...          ...         ...        ...  ...      ...      ...     ...
# 120167      PATH           0       None  ...     None        2      NV
# 120168      PATH           0       None  ...     None        2      NV
# 120169       AVE  1322600287         TF  ...        C        2      TF
# 120170       AVE  1322600287         TF  ...        C        2      TF
# 120171       AVE           0       None  ...        C        2      TF
#
#        pre_modifi                    st_label physicalid  \
# 0            None                  BATTERY PL          3
# 1            None                  BATTERY PL          5
# 2            None                  BATTERY PL          6
# 3            None                  BATTERY PL          8
# 4            None                  BATTERY PL         14
# ...           ...                         ...        ...
# 120167       None  CO-OP CITY PEDESTRIAN PATH     192222
# 120168       None  CO-OP CITY PEDESTRIAN PATH     192223
# 120169       None                       3 AVE     192224
# 120170       None                       3 AVE     192226
# 120171       None                       3 AVE     192228
#
#                      st_name                    created l_high_hn  \
# 0                    BATTERY  2007-11-29T00:00:00+00:00        64
# 1                    BATTERY  2007-11-29T00:00:00+00:00        82
# 2                    BATTERY  2007-11-29T00:00:00+00:00        98
# 3                    BATTERY  2007-11-29T00:00:00+00:00      None
# 4                    BATTERY  2007-11-29T00:00:00+00:00      None
# ...                      ...                        ...       ...
# 120167  COOP CITY PEDESTRIAN  2021-06-04T00:00:00+00:00      None
# 120168  COOP CITY PEDESTRIAN  2021-06-04T00:00:00+00:00      None
# 120169                 THIRD  2007-11-29T00:00:00+00:00      None
# 120170                 THIRD  2007-11-29T00:00:00+00:00      None
# 120171                 THIRD  2007-11-29T00:00:00+00:00      None
#
#                                                  geometry
# 0       MULTILINESTRING ((-74.01793 40.70617, -74.0178...
# 1       MULTILINESTRING ((-74.01757 40.70684, -74.0171...
# 2       MULTILINESTRING ((-74.01712 40.70746, -74.0166...
# 3       MULTILINESTRING ((-74.01694 40.70481, -74.0170...
# 4       MULTILINESTRING ((-74.01429 40.70455, -74.0143...
# ...                                                   ...
# 120167  MULTILINESTRING ((-73.82562 40.87750, -73.8251...
# 120168  MULTILINESTRING ((-73.82562 40.87750, -73.8254...
# 120169  MULTILINESTRING ((-73.92931 40.80948, -73.9292...
# 120170  MULTILINESTRING ((-73.92936 40.80944, -73.9293...
# 120171  MULTILINESTRING ((-73.92941 40.80940, -73.9293...
#
# [120172 rows x 32 columns]

# %%
scl.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 120172 entries, 0 to 120171
# Data columns (total 32 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   rw_type     120172 non-null  object
#  1   l_low_hn    84255 non-null   object
#  2   pre_direct  9780 non-null    object
#  3   st_width    120172 non-null  object
#  4   r_zip       118873 non-null  object
#  5   r_low_hn    84255 non-null   object
#  6   bike_lane   14606 non-null   object
#  7   post_type   102019 non-null  object
#  8   r_blkfc_id  120172 non-null  object
#  9   bike_trafd  14559 non-null   object
#  10  frm_lvl_co  120172 non-null  object
#  11  post_modif  604 non-null     object
#  12  pre_type    1535 non-null    object
#  13  full_stree  120172 non-null  object
#  14  l_blkfc_id  120172 non-null  object
#  15  shape_leng  120172 non-null  object
#  16  to_lvl_co   120172 non-null  object
#  17  modified    119907 non-null  object
#  18  status      120172 non-null  object
#  19  post_direc  1839 non-null    object
#  20  r_high_hn   84255 non-null   object
#  21  l_zip       118798 non-null  object
#  22  snow_pri    109713 non-null  object
#  23  borocode    120172 non-null  object
#  24  trafdir     120171 non-null  object
#  25  pre_modifi  140 non-null     object
#  26  st_label    120172 non-null  object
#  27  physicalid  120172 non-null  object
#  28  st_name     120172 non-null  object
#  29  created     120172 non-null  object
#  30  l_high_hn   84255 non-null   object
#  31  geometry    120172 non-null  geometry
# dtypes: geometry(1), object(31)
# memory usage: 29.3+ MB

# %%
scl= scl[['rw_type','bike_lane','snow_pri','borocode','st_label','physicalid','geometry']]
scl
# Out:
#        rw_type bike_lane snow_pri borocode                    st_label  \
# 0            1      None        C        1                  BATTERY PL
# 1            1      None        C        1                  BATTERY PL
# 2            1      None        C        1                  BATTERY PL
# 3            1      None        C        1                  BATTERY PL
# 4            1      None        C        1                  BATTERY PL
# ...        ...       ...      ...      ...                         ...
# 120167       6      None     None        2  CO-OP CITY PEDESTRIAN PATH
# 120168       6      None     None        2  CO-OP CITY PEDESTRIAN PATH
# 120169       1         2        C        2                       3 AVE
# 120170       1         2        C        2                       3 AVE
# 120171       1      None        C        2                       3 AVE
#
#        physicalid                                           geometry
# 0               3  MULTILINESTRING ((-74.01793 40.70617, -74.0178...
# 1               5  MULTILINESTRING ((-74.01757 40.70684, -74.0171...
# 2               6  MULTILINESTRING ((-74.01712 40.70746, -74.0166...
# 3               8  MULTILINESTRING ((-74.01694 40.70481, -74.0170...
# 4              14  MULTILINESTRING ((-74.01429 40.70455, -74.0143...
# ...           ...                                                ...
# 120167     192222  MULTILINESTRING ((-73.82562 40.87750, -73.8251...
# 120168     192223  MULTILINESTRING ((-73.82562 40.87750, -73.8254...
# 120169     192224  MULTILINESTRING ((-73.92931 40.80948, -73.9292...
# 120170     192226  MULTILINESTRING ((-73.92936 40.80944, -73.9293...
# 120171     192228  MULTILINESTRING ((-73.92941 40.80940, -73.9293...
#
# [120172 rows x 7 columns]

# %%
#rename columns
scl = scl.rename(columns={
    'rw_type':'roadway_type',
    'snow_pri':'snow_priority',
    'borocode':'boro_code',
    'st_label':'roadway_name',
    'physicalid':'street_id'
})

# %%
#fix nones
scl['bike_lane'] = scl['bike_lane'].fillna(0)
scl['snow_priority'] = scl['snow_priority'].fillna('N')

# %%
#lower case
scl['roadway_name'] = scl['roadway_name'].str.lower()

# %%
#fix abbreviations
scl['roadway_name'] = scl['roadway_name'].str.replace(' blvd', ' boulevard') 
scl['roadway_name'] = scl['roadway_name'].str.replace(' e ', 'east ') 
scl['roadway_name'] = scl['roadway_name'].str.replace(' w ', 'west ') 
scl['roadway_name'] = scl['roadway_name'].str.replace(' pkwy', ' parkway') 
scl['roadway_name'] = scl['roadway_name'].str.replace(' pl', ' place') 
scl['roadway_name'] = scl['roadway_name'].str.replace(' st', ' street') 
scl['roadway_name'] = scl['roadway_name'].str.replace(' rd', ' road')
scl['roadway_name'] = scl['roadway_name'].str.replace(' ave', ' avenue')
scl['roadway_name'] = scl['roadway_name'].str.replace('ave ', 'avenue ')
scl['roadway_name'] = scl['roadway_name'].str.replace(' ln', ' lane')
scl['roadway_name'] = scl['roadway_name'].str.replace(' dvwy', ' driveway')
scl['roadway_name'] = scl['roadway_name'].str.replace(' dr', ' drive')
scl['roadway_name'] = scl['roadway_name'].str.replace(' expy', ' expresspway')
scl['roadway_name'] = scl['roadway_name'].str.replace(' tunl', ' tunnel')
scl['roadway_name'] = scl['roadway_name'].str.replace(' brg', ' bridge')
scl['roadway_name'] = scl['roadway_name'].str.replace(' sq', ' square')
scl['roadway_name'] = scl['roadway_name'].str.replace(' plz', ' plaza')
scl['roadway_name'] = scl['roadway_name'].str.replace(' cir', ' circle')
scl['roadway_name'] = scl['roadway_name'].str.replace(' tpke', ' turnpike')
scl['roadway_name'] = scl['roadway_name'].str.replace(' cres', ' crescent')
scl['roadway_name'] = scl['roadway_name'].str.replace(' fwy', ' freeway')
scl['roadway_name'] = scl['roadway_name'].str.replace(' appr ', ' approach')
scl['roadway_name'] = scl['roadway_name'].str.replace(' lk', ' lake')
scl['roadway_name'] = scl['roadway_name'].str.replace(' hwy', ' highway')
scl['roadway_name'] = scl['roadway_name'].str.replace(' hts', ' heights')
scl['roadway_name'] = scl['roadway_name'].str.replace(' grn', ' green')
scl['roadway_name'] = scl['roadway_name'].str.replace(' pth', ' path')
scl['roadway_name'] = scl['roadway_name'].str.replace(' drwy', ' driveway')
scl['roadway_name'] = scl['roadway_name'].str.replace(' rdg', ' ridge')
