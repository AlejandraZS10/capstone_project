# %%
import pandas as pd
import geopandas as gpd

#traffic volume csv
traffic=pd.read_csv('https://raw.githubusercontent.com/AlejandraZS10/capstone_project/master/Traffic_Volume_Counts__2014-2019_.csv')
traffic.head(10)
# Out:
#    ID  Segment ID            Roadway Name                From  \
# 0   2       70376                3 Avenue     East 154 Street
# 1   2       70376                3 Avenue     East 155 Street
# 2  56      176365  Bedford Park Boulevard     Grand Concourse
# 3  56      176365  Bedford Park Boulevard     Grand Concourse
# 4  62      147673                Broadway     West 242 Street
# 5  62      158447                Broadway     West 242 Street
# 6  62      255653                Broadway     West 242 Street
# 7  71      139620     Bronx River Parkway         Bronx River
# 8  71      139618     Bronx River Parkway  East Gun Hill Road
# 9  76       70364            Brook Avenue     East 152 Street
#
#                    To Direction        Date  12:00-1:00 AM  1:00-2:00AM  \
# 0     East 155 Street        NB  09/13/2014          204.0        177.0
# 1     East 154 Street        SB  09/13/2014          140.0         51.0
# 2    Valentine Avenue        EB  09/13/2014           94.0         73.0
# 3    Valentine Avenue        WB  09/13/2014           88.0         82.0
# 4          240 Street        SB  09/13/2014          255.0        209.0
# 5          240 Street        NB  09/13/2014          255.0        209.0
# 6          240 Street        SB  09/13/2014           87.0         86.0
# 7  East Gun Hill Road        NB  09/13/2014          802.0        445.0
# 8         Bronx River        SB  09/13/2014          618.0        345.0
# 9     East 153 Street        SB  09/13/2014           79.0         58.0
#
#    2:00-3:00AM  ...  2:00-3:00PM  3:00-4:00PM  4:00-5:00PM  5:00-6:00PM  \
# 0        133.0  ...          520          611          573          546
# 1        128.0  ...          379          376          329          362
# 2         65.0  ...          280          272          264          236
# 3         75.0  ...          237          276          223          240
# 4        149.0  ...          732          809          707          675
# 5        149.0  ...          732          809          707          675
# 6         78.0  ...          200          200          209          175
# 7        388.0  ...         2933         2904         2699         2877
# 8        309.0  ...         2676         2848         2680         2581
# 9         41.0  ...          288          300          301          305
#
#    6:00-7:00PM  7:00-8:00PM  8:00-9:00PM  9:00-10:00PM  10:00-11:00PM  \
# 0          582          528          432           328            282
# 1          418          335          282           247            237
# 2          213          190          199           183            147
# 3          217          198          186           162            157
# 4          641          556          546           465            425
# 5          641          556          546           465            425
# 6          181          167          144           129            112
# 7         2947         2532         2193          1820           1677
# 8         2274         2054         1762          1534           1308
# 9          294          222          183           134            129
#
#    11:00-12:00AM
# 0            240
# 1            191
# 2            103
# 3            103
# 4            324
# 5            324
# 6            103
# 7           1331
# 8           1107
# 9             97
#
# [10 rows x 31 columns]

# %%
# get the basic data info
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27289 entries, 0 to 27288
# Data columns (total 31 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             27289 non-null  int64
#  1   Segment ID     27289 non-null  int64
#  2   Roadway Name   27289 non-null  object
#  3   From           27289 non-null  object
#  4   To             27289 non-null  object
#  5   Direction      27289 non-null  object
#  6   Date           27289 non-null  object
#  7   12:00-1:00 AM  27285 non-null  float64
#  8   1:00-2:00AM    27285 non-null  float64
#  9   2:00-3:00AM    27285 non-null  float64
#  10  3:00-4:00AM    27285 non-null  float64
#  11  4:00-5:00AM    27285 non-null  float64
#  12  5:00-6:00AM    27285 non-null  float64
#  13  6:00-7:00AM    27285 non-null  float64
#  14  7:00-8:00AM    27285 non-null  float64
#  15  8:00-9:00AM    27285 non-null  float64
#  16  9:00-10:00AM   27285 non-null  float64
#  17  10:00-11:00AM  27286 non-null  float64
#  18  11:00-12:00PM  27288 non-null  float64
#  19  12:00-1:00PM   27289 non-null  int64
#  20  1:00-2:00PM    27289 non-null  int64
#  21  2:00-3:00PM    27289 non-null  int64
#  22  3:00-4:00PM    27289 non-null  int64
#  23  4:00-5:00PM    27289 non-null  int64
#  24  5:00-6:00PM    27289 non-null  int64
#  25  6:00-7:00PM    27289 non-null  int64
#  26  7:00-8:00PM    27289 non-null  int64
#  27  8:00-9:00PM    27289 non-null  int64
#  28  9:00-10:00PM   27289 non-null  int64
#  29  10:00-11:00PM  27289 non-null  int64
#  30  11:00-12:00AM  27289 non-null  int64
# dtypes: float64(12), int64(14), object(5)
# memory usage: 6.5+ MB

# %%
traffic['Date']=pd.to_datetime(traffic.Date, format="%m/%d/%Y")

# %%
traffic['year'] = traffic['Date'].dt.year

traffic['month'] = traffic['Date'].dt.month

traffic['day'] = traffic['Date'].dt.day

traffic.head()
# Out:
#    ID  Segment ID            Roadway Name             From                To  \
# 0   2       70376                3 Avenue  East 154 Street   East 155 Street
# 1   2       70376                3 Avenue  East 155 Street   East 154 Street
# 2  56      176365  Bedford Park Boulevard  Grand Concourse  Valentine Avenue
# 3  56      176365  Bedford Park Boulevard  Grand Concourse  Valentine Avenue
# 4  62      147673                Broadway  West 242 Street        240 Street
#
#   Direction       Date  12:00-1:00 AM  1:00-2:00AM  2:00-3:00AM  ...  \
# 0        NB 2014-09-13          204.0        177.0        133.0  ...
# 1        SB 2014-09-13          140.0         51.0        128.0  ...
# 2        EB 2014-09-13           94.0         73.0         65.0  ...
# 3        WB 2014-09-13           88.0         82.0         75.0  ...
# 4        SB 2014-09-13          255.0        209.0        149.0  ...
#
#    5:00-6:00PM  6:00-7:00PM  7:00-8:00PM  8:00-9:00PM  9:00-10:00PM  \
# 0          546          582          528          432           328
# 1          362          418          335          282           247
# 2          236          213          190          199           183
# 3          240          217          198          186           162
# 4          675          641          556          546           465
#
#    10:00-11:00PM  11:00-12:00AM  year  month  day
# 0            282            240  2014      9   13
# 1            237            191  2014      9   13
# 2            147            103  2014      9   13
# 3            157            103  2014      9   13
# 4            425            324  2014      9   13
#
# [5 rows x 34 columns]

# %%
# statistical values
traffic.describe()
# Out:
#                  ID    Segment ID  12:00-1:00 AM   1:00-2:00AM   2:00-3:00AM  \
# count  27289.000000  2.728900e+04   27285.000000  27285.000000  27285.000000
# mean     178.367584  6.460915e+05     294.463955    208.562800    156.573355
# std      107.494863  2.155932e+06     460.922628    337.987268    264.599920
# min        1.000000  2.020000e+02       0.000000      0.000000      0.000000
# 25%       85.000000  3.504100e+04      67.000000     42.000000     30.000000
# 50%      172.000000  8.169400e+04     132.000000     89.000000     64.000000
# 75%      272.000000  1.481960e+05     283.000000    203.000000    151.000000
# max      372.000000  9.017050e+06    4805.000000   3841.000000   3867.000000
#
#         3:00-4:00AM   4:00-5:00AM   5:00-6:00AM   6:00-7:00AM   7:00-8:00AM  \
# count  27285.000000  27285.000000  27285.000000  27285.000000  27285.000000
# mean     136.433058    160.225325    248.728972    418.841195    563.831592
# std      234.929296    282.590405    487.478933    721.341289    795.208685
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       25.000000     31.000000     47.000000     83.000000    141.000000
# 50%       54.000000     64.000000     95.000000    174.000000    296.000000
# 75%      130.000000    149.000000    211.000000    387.000000    601.000000
# max     3512.000000   4469.000000   6456.000000   7513.000000   8276.000000
#
#        ...   5:00-6:00PM   6:00-7:00PM   7:00-8:00PM   8:00-9:00PM  \
# count  ...  27289.000000  27289.000000  27289.000000  27289.000000
# mean   ...    745.269523    718.137711    658.413060    578.596614
# std    ...    878.633899    874.065350    840.847796    780.646610
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...    273.000000    253.000000    222.000000    182.000000
# 50%    ...    453.000000    428.000000    378.000000    315.000000
# 75%    ...    802.000000    759.000000    669.000000    567.000000
# max    ...   9762.000000   9879.000000  10532.000000   6659.000000
#
#        9:00-10:00PM  10:00-11:00PM  11:00-12:00AM          year         month  \
# count  27289.000000   27289.000000   27289.000000  27289.000000  27289.000000
# mean     501.990472     442.655319     370.144490   2016.240646      9.582946
# std      706.233853     647.283718     560.621224      1.824664      1.847119
# min        0.000000       0.000000       0.000000   2014.000000      1.000000
# 25%      148.000000     120.000000      91.000000   2015.000000      9.000000
# 50%      261.000000     218.000000     175.000000   2016.000000     10.000000
# 75%      482.000000     420.000000     351.000000   2018.000000     10.000000
# max     5698.000000    5460.000000    5027.000000   2019.000000     12.000000
#
#                 day
# count  27289.000000
# mean      13.954414
# std        8.008619
# min        1.000000
# 25%        8.000000
# 50%       13.000000
# 75%       19.000000
# max       31.000000
#
# [8 rows x 29 columns]

# %%
# import libraries for plotting
from string import ascii_letters
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# plot histograms and box plot of each attribute
for i in traffic.iloc[:,7:].columns:
    fig, axes = plt.subplots(1, 2,figsize=(10,4))
    sns.boxplot(ax=axes[0], y = i, data = traffic,orient='v')
    sns.histplot(data=traffic, ax=axes[1], x = i, bins=10)
# Out:
# /Users/alejandrazapatasoveranez/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   # Remove the CWD from sys.path while we load stuff.
# /Users/alejandrazapatasoveranez/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   # Remove the CWD from sys.path while we load stuff.
# /Users/alejandrazapatasoveranez/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   # Remove the CWD from sys.path while we load stuff.
# /Users/alejandrazapatasoveranez/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   # Remove the CWD from sys.path while we load stuff.

# %%
# plot traffic volume over time
for i in traffic.iloc[:,7:-4].columns:
    fig, axes = plt.subplots(1, 1,figsize=(10,4))
    sns.lineplot(data=traffic, x="Date", y= i, hue='month')
# Out:
# /Users/alejandrazapatasoveranez/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/alejandrazapatasoveranez/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/alejandrazapatasoveranez/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
sns.countplot(x='Direction', data=traffic)

# %%
traffic['Roadway Name'].value_counts()
# Out:
# Broadway                  387
# 3 Avenue                  198
# Southern Boulevard        184
# 3 AVENUE                  181
# BROADWAY                  153
#                          ...
# Montrose Avenue             9
# KINGSLAND AVENUE            9
# 5th AVENUE                  6
# East 170  Main Road         1
# East 170  Service Road      1
# Name: Roadway Name, Length: 889, dtype: int64

# %%
sns.heatmap(traffic.corr(),linewidths=.20)

# %%
traffic['morning_rush'] = traffic['6:00-7:00AM'] + traffic['8:00-9:00AM'] + traffic['10:00-11:00AM']
traffic['midday'] = traffic['12:00-1:00PM'] + traffic['2:00-3:00PM']
traffic['afternoon_rush'] = traffic['4:00-5:00PM'] + traffic['6:00-7:00PM']
traffic['evening'] = traffic['8:00-9:00PM'] + traffic['10:00-11:00PM'] + traffic['12:00-1:00 AM']
traffic['night'] = traffic['2:00-3:00AM'] + traffic['4:00-5:00AM'] 
traffic.head(4)
# Out:
#    ID  Segment ID            Roadway Name             From                To  \
# 0   2       70376                3 Avenue  East 154 Street   East 155 Street
# 1   2       70376                3 Avenue  East 155 Street   East 154 Street
# 2  56      176365  Bedford Park Boulevard  Grand Concourse  Valentine Avenue
# 3  56      176365  Bedford Park Boulevard  Grand Concourse  Valentine Avenue
#
#   Direction       Date  12:00-1:00 AM  1:00-2:00AM  2:00-3:00AM  ...  \
# 0        NB 2014-09-13          204.0        177.0        133.0  ...
# 1        SB 2014-09-13          140.0         51.0        128.0  ...
# 2        EB 2014-09-13           94.0         73.0         65.0  ...
# 3        WB 2014-09-13           88.0         82.0         75.0  ...
#
#    10:00-11:00PM  11:00-12:00AM  year  month  day  morning_rush  midday  \
# 0            282            240  2014      9   13         730.0    1033
# 1            237            191  2014      9   13         696.0     782
# 2            147            103  2014      9   13         416.0     524
# 3            157            103  2014      9   13         474.0     494
#
#    afternoon_rush  evening  night
# 0            1155    918.0  274.0
# 1             747    659.0  272.0
# 2             477    440.0  129.0
# 3             440    431.0  140.0
#
# [4 rows x 39 columns]

# %%
traffic[traffic['']]
# Out:
#         ID  Segment ID            Roadway Name             From  \
# 2       56      176365  Bedford Park Boulevard  Grand Concourse
# 3       56      176365  Bedford Park Boulevard  Grand Concourse
# 4       62      147673                Broadway  West 242 Street
# 5       62      158447                Broadway  West 242 Street
# 6       62      255653                Broadway  West 242 Street
# ...    ...         ...                     ...              ...
# 27257  369      103545          Woolley Avenue  Westwood Avenue
# 27258  369      103545          Woolley Avenue  Westwood Avenue
# 27259  369      103545          Woolley Avenue  Westwood Avenue
# 27260  369      103545          Woolley Avenue  Westwood Avenue
# 27261  369      103545          Woolley Avenue  Westwood Avenue
#
#                      To Direction       Date  12:00-1:00 AM  1:00-2:00AM  \
# 2      Valentine Avenue        EB 2014-09-13           94.0         73.0
# 3      Valentine Avenue        WB 2014-09-13           88.0         82.0
# 4            240 Street        SB 2014-09-13          255.0        209.0
# 5            240 Street        NB 2014-09-13          255.0        209.0
# 6            240 Street        SB 2014-09-13           87.0         86.0
# ...                 ...       ...        ...            ...          ...
# 27257     Dawson Street        NB 2019-09-25           59.0         32.0
# 27258     Dawson Street        NB 2019-09-26           73.0         40.0
# 27259     Dawson Street        NB 2019-09-27          107.0         39.0
# 27260     Dawson Street        NB 2019-09-28          139.0         76.0
# 27261     Dawson Street        NB 2019-09-29          127.0         96.0
#
#        2:00-3:00AM  ...  10:00-11:00PM  11:00-12:00AM  year  month  day  \
# 2             65.0  ...            147            103  2014      9   13
# 3             75.0  ...            157            103  2014      9   13
# 4            149.0  ...            425            324  2014      9   13
# 5            149.0  ...            425            324  2014      9   13
# 6             78.0  ...            112            103  2014      9   13
# ...            ...  ...            ...            ...   ...    ...  ...
# 27257         20.0  ...            237            144  2019      9   25
# 27258         25.0  ...            218            163  2019      9   26
# 27259         22.0  ...            296            212  2019      9   27
# 27260         44.0  ...            297            206  2019      9   28
# 27261         55.0  ...            193            115  2019      9   29
#
#        morning_rush  midday  afternoon_rush  evening  night
# 2             416.0     524             477    440.0  129.0
# 3             474.0     494             440    431.0  140.0
# 4            1306.0    1517            1348   1226.0  277.0
# 5            1306.0    1517            1348   1226.0  277.0
# 6             484.0     439             390    343.0  125.0
# ...             ...     ...             ...      ...    ...
# 27257        1555.0     935            1006    655.0  154.0
# 27258        1614.0     945            1036    673.0  144.0
# 27259        1593.0    1061            1015    790.0  160.0
# 27260        1024.0    1068            1047    821.0  108.0
# 27261         950.0    1019             965    616.0   95.0
#
# [15718 rows x 39 columns]

# %%
#traffic['SurroundingTraffic']= i for i in len(range(traffic)) if 
traffic['RoadwayName'] == traffic['From'] | traffic['To'] & 
traffic['From']== traffic['RoadwayName'] | 
traffic['To']== traffic['RoadwayName']

# %%
traffic.loc[traffic['To'] == 'East 155 Street']
# Out:
#        ID  Segment ID Roadway Name             From               To  \
# 0       2       70376     3 Avenue  East 154 Street  East 155 Street
# 72      2       70376     3 Avenue  East 154 Street  East 155 Street
# 143     2       70376     3 Avenue  East 154 Street  East 155 Street
# 215     2       70376     3 Avenue  East 154 Street  East 155 Street
# 287     2       70376     3 Avenue  East 154 Street  East 155 Street
# 359     2       70376     3 Avenue  East 154 Street  East 155 Street
# 431     2       70376     3 Avenue  East 154 Street  East 155 Street
# 502     2       70376     3 Avenue  East 154 Street  East 155 Street
# 660     2       70376     3 Avenue  East 154 Street  East 155 Street
# 16138  19       70376     3 Avenue  East 154 Street  East 155 Street
# 16139  19       70376     3 Avenue  East 154 Street  East 155 Street
# 16231  19       70376     3 Avenue  East 154 Street  East 155 Street
# 16232  19       70376     3 Avenue  East 154 Street  East 155 Street
# 16324  19       70376     3 Avenue  East 154 Street  East 155 Street
# 16325  19       70376     3 Avenue  East 154 Street  East 155 Street
# 16418  19       70376     3 Avenue  East 154 Street  East 155 Street
# 16419  19       70376     3 Avenue  East 154 Street  East 155 Street
# 16511  19       70376     3 Avenue  East 154 Street  East 155 Street
# 16512  19       70376     3 Avenue  East 154 Street  East 155 Street
# 16604  19       70376     3 Avenue  East 154 Street  East 155 Street
# 16605  19       70376     3 Avenue  East 154 Street  East 155 Street
# 16697  19       70376     3 Avenue  East 154 Street  East 155 Street
# 16698  19       70376     3 Avenue  East 154 Street  East 155 Street
# 16793  19       70376     3 Avenue  East 154 Street  East 155 Street
# 16794  19       70376     3 Avenue  East 154 Street  East 155 Street
# 16956  19       70376     3 Avenue  East 154 Street  East 155 Street
# 16957  19       70376     3 Avenue  East 154 Street  East 155 Street
#
#       Direction       Date  12:00-1:00 AM  1:00-2:00AM  2:00-3:00AM  ...  \
# 0            NB 2014-09-13          204.0        177.0        133.0  ...
# 72           NB 2014-09-14          215.0        213.0        162.0  ...
# 143          NB 2014-09-15          118.0         99.0         67.0  ...
# 215          NB 2014-09-16          135.0        107.0         48.0  ...
# 287          NB 2014-09-17          138.0         95.0         59.0  ...
# 359          NB 2014-09-18          149.0         79.0         77.0  ...
# 431          NB 2014-09-19          141.0        108.0         95.0  ...
# 502          NB 2014-09-20          235.0        198.0        139.0  ...
# 660          NB 2014-09-21          204.0        183.0        145.0  ...
# 16138        NB 2017-09-23          323.0        196.0        164.0  ...
# 16139        SB 2017-09-23          188.0        137.0        133.0  ...
# 16231        NB 2017-09-24          292.0        212.0        168.0  ...
# 16232        SB 2017-09-24          187.0        201.0        141.0  ...
# 16324        NB 2017-09-25          153.0        127.0         91.0  ...
# 16325        SB 2017-09-25          115.0         82.0         72.0  ...
# 16418        NB 2017-09-26          154.0        120.0         74.0  ...
# 16419        SB 2017-09-26          115.0         90.0         54.0  ...
# 16511        NB 2017-09-27          161.0        114.0         79.0  ...
# 16512        SB 2017-09-27          121.0         97.0         46.0  ...
# 16604        NB 2017-09-28          148.0        138.0         91.0  ...
# 16605        SB 2017-09-28          101.0         82.0         68.0  ...
# 16697        NB 2017-09-29          154.0        145.0        104.0  ...
# 16698        SB 2017-09-29          128.0         96.0         60.0  ...
# 16793        NB 2017-09-30          301.0        204.0        166.0  ...
# 16794        SB 2017-09-30          209.0        144.0        117.0  ...
# 16956        NB 2017-10-01          238.0        215.0        156.0  ...
# 16957        SB 2017-10-01          196.0        156.0        136.0  ...
#
#        10:00-11:00PM  11:00-12:00AM  year  month  day  morning_rush  midday  \
# 0                282            240  2014      9   13         730.0    1033
# 72               234            193  2014      9   14         573.0     905
# 143              216            173  2014      9   15        1158.0    1001
# 215              201            167  2014      9   16        1079.0     992
# 287              212            163  2014      9   17        1084.0     881
# 359              248            183  2014      9   18        1042.0     823
# 431              289            271  2014      9   19        1229.0    1016
# 502              283            265  2014      9   20         736.0     836
# 660              213            205  2014      9   21         523.0     759
# 16138            312            291  2017      9   23         679.0    1147
# 16139            253            210  2017      9   23         704.0     612
# 16231            275            207  2017      9   24         510.0     815
# 16232            218            154  2017      9   24         505.0     562
# 16324            238            193  2017      9   25        1306.0    1134
# 16325            149            119  2017      9   25         970.0     706
# 16418            244            183  2017      9   26        1197.0    1003
# 16419            171            121  2017      9   26         954.0     567
# 16511            218            234  2017      9   27        1084.0    1070
# 16512            166            117  2017      9   27         898.0     652
# 16604            256            209  2017      9   28        1193.0    1062
# 16605            196            158  2017      9   28         926.0     633
# 16697            351            311  2017      9   29        1189.0    1260
# 16698            260            213  2017      9   29         908.0     602
# 16793            292            284  2017      9   30         781.0    1090
# 16794            217            194  2017      9   30         674.0     627
# 16956            262            182  2017     10    1         549.0     942
# 16957            188            134  2017     10    1         509.0     683
#
#        afternoon_rush  evening  night
# 0                1155    918.0  274.0
# 72               1040    777.0  319.0
# 143              1254    678.0  117.0
# 215              1184    670.0  108.0
# 287              1190    727.0  117.0
# 359              1250    800.0  149.0
# 431              1280    831.0  175.0
# 502              1214    963.0  294.0
# 660               997    725.0  300.0
# 16138            1223   1075.0  276.0
# 16139             721    714.0  228.0
# 16231             940    925.0  329.0
# 16232             638    627.0  270.0
# 16324            1222    788.0  159.0
# 16325             350    519.0  145.0
# 16418            1218    781.0  143.0
# 16419             738    523.0  116.0
# 16511            1127    748.0  140.0
# 16512             616    531.0  106.0
# 16604            1293    835.0  168.0
# 16605             604    550.0  148.0
# 16697            1295   1016.0  191.0
# 16698             640    689.0  130.0
# 16793            1220   1060.0  278.0
# 16794             673    711.0  234.0
# 16956             963    892.0  309.0
# 16957             627    634.0  238.0
#
# [27 rows x 39 columns]

# %%
traffic[(traffic['To']==traffic['Roadway Name']) ]
        #| (traffic["To"]==traffic['Roadway Name'])]
# Out:
# Empty DataFrame
# Columns: [ID, Segment ID, Roadway Name, From, To, Direction, Date, 12:00-1:00 AM, 1:00-2:00AM, 2:00-3:00AM, 3:00-4:00AM, 4:00-5:00AM, 5:00-6:00AM, 6:00-7:00AM, 7:00-8:00AM, 8:00-9:00AM, 9:00-10:00AM, 10:00-11:00AM, 11:00-12:00PM, 12:00-1:00PM, 1:00-2:00PM, 2:00-3:00PM, 3:00-4:00PM, 4:00-5:00PM, 5:00-6:00PM, 6:00-7:00PM, 7:00-8:00PM, 8:00-9:00PM, 9:00-10:00PM, 10:00-11:00PM, 11:00-12:00AM, year, month, day, morning_rush, midday, afternoon_rush, evening, night]
# Index: []
#
# [0 rows x 39 columns]
